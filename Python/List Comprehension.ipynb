# %%
even = list(filter(lambda x: x % 2 == 0 , range (1, 10)))

print (even)
# Out:
# [2, 4, 6, 8]

# %%
even = []

for i in range (1, 10):
    if i % 2 == 0:
        print (i)
# Out:
# 2
# 4
# 6
# 8

# %%
[i for i in range (1,20) if i %2 == 0]
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %%
numbers = []
for i in range (1, 10):
    if i % 2 ==0:
        numbers.append("even")
    else:
        numbers.append("odd")
print (numbers)
# Out:
# ['odd', 'even', 'odd', 'even', 'odd', 'even', 'odd', 'even', 'odd']

# %%
string = "missicippie"
#use dictionary/ tuples
#convert into set, use count functon. For each letter use count store it in dictonary

# %%
# Python program to sum the given series 
  
# Returns sum of n + nn + nnn + .... (m times) 
def Series(n, m): 
  
    # Converting the number to string 
    str_n = str(n) 
  
    # Initializing result as number and string 
    sums = n 
    sum_str = str(n) 
  
    # Adding remaining terms 
    for i in range(1, m): 
         
        # Concatenating the string making n, nn, nnn... 
        sum_str = sum_str + str_n 
          
        # Before adding converting back to integer 
        sums = sums + int(sum_str) 
  
    return sums 
  
# Driver Code 
n = 2
m = 5
total = Series(n, m) 
print(total)
# Out:
# 24690

# %%
for i in range (1, 21):
    if i % 2 ==0:
        print ("Divisible by 2", i)
    elif i % 3 == 0:
        print ("Divisible by 3", i)
    else:
        print ("notdivisible by 2 or 3", i)
# Out:
# notdivisible by 2 or 3 1
# Divisible by 2 2
# Divisible by 3 3
# Divisible by 2 4
# notdivisible by 2 or 3 5
# Divisible by 2 6
# notdivisible by 2 or 3 7
# Divisible by 2 8
# Divisible by 3 9
# Divisible by 2 10
# notdivisible by 2 or 3 11
# Divisible by 2 12
# notdivisible by 2 or 3 13
# Divisible by 2 14
# Divisible by 3 15
# Divisible by 2 16
# notdivisible by 2 or 3 17
# Divisible by 2 18
# notdivisible by 2 or 3 19
# Divisible by 2 20

# %%
[("Divisible by 2", i) if i%2==0 else ("Divisible by 3",i) if i%3==0 else ("not divisible by 2 & 3",i) for i in range (1, 21)]
# Out:
# [('not divisible by 2 & 3', 1),
#  ('Divisible by 2', 2),
#  ('Divisible by 3', 3),
#  ('Divisible by 2', 4),
#  ('not divisible by 2 & 3', 5),
#  ('Divisible by 2', 6),
#  ('not divisible by 2 & 3', 7),
#  ('Divisible by 2', 8),
#  ('Divisible by 3', 9),
#  ('Divisible by 2', 10),
#  ('not divisible by 2 & 3', 11),
#  ('Divisible by 2', 12),
#  ('not divisible by 2 & 3', 13),
#  ('Divisible by 2', 14),
#  ('Divisible by 3', 15),
#  ('Divisible by 2', 16),
#  ('not divisible by 2 & 3', 17),
#  ('Divisible by 2', 18),
#  ('not divisible by 2 & 3', 19),
#  ('Divisible by 2', 20)]
