# %%
print ("This is my first line of code Again!!")
# Out:
# This is my first line of code Again!!

# %%
print ("Hi \nHow are you doing?")
# Out:
# Hi
# How are you doing?

# %%
import numpy as np 
import pandas as pd

# Defining the three dataframes indicating the gold, silver, and bronze medal counts
# of different countries
gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

gold=gold.set_index('Country')
silver=silver.set_index('Country')
bronze=bronze.set_index('Country')

print(gold)
print(silver)
print(bronze)

df_1 = gold.add(silver, fill_value=0)
df_2 = df_1.add(bronze, fill_value=0)
df_3 = df_2.sort_values(by = 'Medals', ascending = False)
print (df_3)
# Out:
#          Medals
# Country
# USA          15
# France       13
# Russia        9
#          Medals
# Country
# USA          29
# Germany      20
# Russia       16
#          Medals
# Country
# France       40
# USA          28
# UK           27
#          Medals
# Country
# USA        72.0
# France     53.0
# UK         27.0
# Russia     25.0
# Germany    20.0
