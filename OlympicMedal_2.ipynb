# %%
import numpy as np 
import pandas as pd

gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

print(gold)
print(silver)
print(bronze)
# Out:
#   Country  Medals
# 0     USA      15
# 1  France      13
# 2  Russia       9
#    Country  Medals
# 0      USA      29
# 1  Germany      20
# 2   Russia      16
#   Country  Medals
# 0  France      40
# 1     USA      28
# 2      UK      27

# %%
import numpy as np 
import pandas as pd

gold = pd.DataFrame({'Country': ['USA', 'France', 'Russia'],
                         'Medals': [15, 13, 9]}
                    )
silver = pd.DataFrame({'Country': ['USA', 'Germany', 'Russia'],
                        'Medals': [29, 20, 16]}
                    )
bronze = pd.DataFrame({'Country': ['France', 'USA', 'UK'],
                        'Medals': [40, 28, 27]}
                    )

df = gold.add(silver, fill_value=0)
print(df)
# Out:
#          Country  Medals
# 0         USAUSA      44
# 1  FranceGermany      33
# 2   RussiaRussia      25
